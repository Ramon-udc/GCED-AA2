# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/eirasf/GCED-AA2/blob/main/es/lab3/lab3_parte1.ipynb)
# # Práctica 3: Redes neuronales usando PyTorch
# ## Parte 1. Creando nuestro primer modelo de red neuronal
#
# En esta práctica vamos a emplear PyTorch para construir y entrenar modelos de aprendizaje profundo. Para comenzar, veremos las facilidades que presenta para crear las distintas capas de una red neuronal y como dichas capas se pueden combinar para crear una red neuronal.
#
# # Pre-requisitos
#
# ## Instalar paquetes
#
# Para esta primera parte solo necesitaremos `numpy`, `torch` (y `pandas`, `sklearn` y `seaborn` para cargar el conjunto de datos).

# %%
import numpy as np
import torch
import seaborn as sns
import pandas as pd

# %% [markdown]
# # La clase Module en PyTorch
#
# Una de las principales abstracciones en PyTorch es la clase **`torch.nn.Module`**.
# `Module` nos permite implementar capas de una red neuronal, encapsulando tanto **el estado** (los parámetros de la capa, como la matriz de pesos \(\mathbf{W}\) y el vector *bias* \(\mathbf{b}\)) como la **transformación de entrada a salida** (el *forward pass*). Vamos a crear una capa densamente conectada, es decir, una capa donde todas las entradas están conectadas con todas las salidas. Además, y tal cual se hizo en el *Laboratorio 2*, empleará la función *sigmoide* como función de activación.
#
# La mejor manera de implementar nuestra propia capa es extender la clase `Module` e implementar:
#
# 1. **`__init__`**:
#    - Se define la estructura de la capa y se crean los tensores que serán los parámetros entrenables (`torch.nn.Parameter`).
#    - Aquí se puede inicializar todo lo que no dependa del tamaño de la entrada, aunque también se pueden crear parámetros dependientes de la entrada.
#
# 2. **`forward`**:
#    - Aquí se define la transformación de los datos, usando operaciones de PyTorch como `@` (matmul) o funciones de activación (`torch.sigmoid`, `torch.relu`, etc.).
#
# ## Creando una capa
# Vamos a crear nuestra propia capa que va a heredar de la clase `Module` y, por tanto, nos permitirá usarla posteriormente en nuestro *modelo* de red neuronal. Al inicializar esta capa solo le indicaremos el número de salidas, al construirla le pasaremos la *shape* de la entrada e inicializaremos los parámetros aleatoriamente (los pesos $\mathbf{W}$ y el bias $b$). En la llamada (*call*) haremos los cálculos necesarios, teniendo en cuenta que la operación *mathmul* de TensorFlow nos permite realizar la multiplicación de matrices y que la función de activación es *sigmoide* (para ver las funciones de activación https://docs.pytorch.org/docs/main/nn.html#non-linear-activations-weighted-sum-nonlinearity, iremos usando algunas de ellas a lo largo del curso).
#
# Diseña la capa como se ha descrito. Haz que la salida sigmoide sea opcional.

# %%
import torch.nn as nn
import torch

class OurDenseLayer(nn.Module):
    def __init__(self, n_output_nodes, input_dim, no_sigmoid=False):
        super().__init__()
        self.no_sigmoid = no_sigmoid
        self.n_output_nodes = n_output_nodes
        # Definir e inicializar parámetros: una matriz de pesos W y un bias b
        # La inicialización de parámetros es aleatoria
        self.W = nn.Parameter(torch.randn(input_dim, self.n_output_nodes, dtype=torch.float32), requires_grad=True)
        #TODO: declarar el bias
        self.b = nn.Parameter(torch.randn(1, self.n_output_nodes, dtype=torch.float32), requires_grad=True)

    def forward(self, x):
        #Calculo de z usando @
        #TO-DO: definir z
        z = x @ self.W + self.b
        #Aplicamos la función sigmoide si nos lo han pedido
        #TO-DO: definir y
        if not self.no_sigmoid:
            y = torch.sigmoid(z)
        else:
            y = z
        return y

# %% [markdown]
# # Concatenando capas para formar una red
# Vamos a crear una red, que llamaremos *model*, usando las tres capas tal y como se hizo en el *Laboratorio 2*:
#
# 1. La capa $C_0$ consta de 5 unidades. Recibe como entrada el vector $\mathbf{x}$ y produce como salida el vector $\mathbf{h_0}$. Tiene una matriz de pesos $\mathbf{W_0}$ y un vector de bias $\mathbf{b_0}$.
#
# 1. La capa $C_1$ consta de 3 unidades. Recibe como entrada el vector $\mathbf{h_0}$ y produce como salida el vector $\mathbf{h_1}$. Tiene una matriz de pesos $\mathbf{W_1}$ y un vector de bias $\mathbf{b_1}$.
#
# 1. La capa $C_2$ consta de 1 unidad. Recibe como entrada el vector $\mathbf{h_1}$ y produce como salida el vector $\mathbf{y}$. Tiene una matriz de pesos $\mathbf{W_2}$ y un vector de bias $\mathbf{b_2}$. **No tiene activación sigmoide.**

# %%
tamano_entrada = 10 # El conjunto que utilizaremos tiene 10 variables
h0_size = 5
h1_size = 3

class OurNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        # Creamos las capas
        self.layer0 = OurDenseLayer(h0_size, tamano_entrada)
        #TODO- crear las otras dos capas
        self.layer1 = OurDenseLayer(h1_size, h0_size)
        self.layer2 = OurDenseLayer(1, h1_size, no_sigmoid=True)

    def forward(self, x):
        #TODO - Aquí se debería llamar a las distintas capas haciendo el forward pass
        h0 = self.layer0(x)
        h1 = self.layer1(h0)
        y = self.layer2(h1)
        return y

# Instanciamos el modelo
model = OurNetwork()

# %% [markdown]
# ## Cargamos el conjunto de datos
#
# Vamos a emplear el mismo conjunto de datos que en el *Laboratorio 2*.

# %%
from sklearn.preprocessing import StandardScaler

def load_titanic():
    # Cargamos el dataset Titanic desde seaborn
    df = sns.load_dataset('titanic')

    # 1️⃣ Selección de variables relevantes y limpieza
    # Columnas que vamos a usar
    cols = ['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked', 'alone']
    df = df[cols].copy()

    # Eliminamos filas con valores faltantes
    df = df.dropna(subset=['age', 'embarked', 'fare'])

    # 2️⃣ Separar etiquetas y características
    y = df['survived'].to_numpy().astype(np.float32)        # etiquetas como float
    X = df.drop(columns=['survived'])

    # 3️⃣ One-hot encoding para todas las variables categóricas
    categorical_cols = ['pclass', 'sex', 'embarked', 'alone']
    X_encoded = pd.get_dummies(X, columns=categorical_cols, drop_first=True)  # drop_first=True evita multicolinealidad

    # 4️⃣ Variables numéricas
    numeric_cols = ['age', 'sibsp', 'parch', 'fare']
    X_numeric = X_encoded[numeric_cols + [c for c in X_encoded.columns if c not in numeric_cols]]
    scaler = StandardScaler()
    X_numeric[numeric_cols] = scaler.fit_transform(X_numeric[numeric_cols])

    # 5️⃣ Convertir a numpy arrays
    X_np = X_numeric.to_numpy().astype(np.float32)
    y_np = y.reshape(-1, 1).astype(np.float32)  # reshape para que sea (n_samples,1)

    return X_np, y_np

vectores_x, etiquetas = load_titanic()
vectores_x = torch.from_numpy(vectores_x)
etiquetas = torch.from_numpy(etiquetas)

# %% [markdown]
# ## Entrenamiento del modelo
#
# Al igual que hicimos en el *Laboratorio 2* vamos a emplear las funciones de PyTorch para ajustar los parámetros de la red (ahora incluidos en nuestro *model*) de modo que se minimice la función de coste, así indicamos:
#
#  1. La función de pérdida que queremos (entropía cruzada, pero usando logits ya que no hemos puesto salida sigmoide en la última capa).
#  1. El método de optimización a utilizar (descenso de gradiente).

# %%
#TODO - Indica la función de perdida y el algoritmo de descenso de gradiente
# Función de pérdida (Binary Cross Entropy con logits para mejorar la estabilidad numérica del entrenamiento)
fn_perdida = nn.BCEWithLogitsLoss()

optimizador = torch.optim.SGD(model.parameters(), lr=0.1)

# %% [markdown]
# Utilizamos el mismo bucle de entrenamiento que en el *Laboratorio 2*, pero ahora no tenemos la función *predice* y las *VARIABLES* que teníamos que ir ajustando tampoco se han declarado, ¿qué deberíamos usar?

# %%
def paso_entrenamiento(x, y):
    # TODO - Completa la siguiente línea para que calcule las predicciones
    y_pred = model(x)

    # Cálculo de la pérdida utilizando la función que hemos escogido anteriormente
    perdida = fn_perdida(y_pred, y)

    # TODO - Completa el resto del bucle de entrenamiento
    optimizador.zero_grad()
    perdida.backward()
    optimizador.step()

    # Tasa de acierto (accuracy)
    fallos = torch.abs(y.reshape(-1,1) - torch.sigmoid(y_pred))
    tasa_acierto = torch.sum(1 - fallos)

    # Devolvemos estos dos valores para poder mostrarlos por pantalla cuando estimemos conveniente
    return (perdida, tasa_acierto)

# PROCESO DE ENTRENAMIENTO
num_epochs = 10000
num_elems = vectores_x.shape[0]

for epoch in range(num_epochs):
    perdida, tasa_error = paso_entrenamiento(vectores_x, etiquetas)

    if epoch % 100 == 99:
        print("Epoch:", epoch, 'Pérdida:', perdida.detach().numpy(), 'Tasa de acierto:', tasa_error.detach().numpy()/num_elems)
# Out:
# Epoch: 99 Pérdida: 0.63627964 Tasa de acierto: 0.5429263
# Epoch: 199 Pérdida: 0.6224427 Tasa de acierto: 0.55195105
# Epoch: 299 Pérdida: 0.6066531 Tasa de acierto: 0.56288683
# Epoch: 399 Pérdida: 0.58928263 Tasa de acierto: 0.5755546
# Epoch: 499 Pérdida: 0.5709037 Tasa de acierto: 0.58955824
# Epoch: 599 Pérdida: 0.5521286 Tasa de acierto: 0.6043742
# Epoch: 699 Pérdida: 0.5336116 Tasa de acierto: 0.6194215
# Epoch: 799 Pérdida: 0.5160257 Tasa de acierto: 0.6340996
# Epoch: 899 Pérdida: 0.49988598 Tasa de acierto: 0.64787996
# Epoch: 999 Pérdida: 0.48540387 Tasa de acierto: 0.6604313
# Epoch: 1099 Pérdida: 0.47254527 Tasa de acierto: 0.67167085
# Epoch: 1199 Pérdida: 0.46122253 Tasa de acierto: 0.68168634
# Epoch: 1299 Pérdida: 0.45142666 Tasa de acierto: 0.69059646
# Epoch: 1399 Pérdida: 0.44323495 Tasa de acierto: 0.6984382
# Epoch: 1499 Pérdida: 0.43665686 Tasa de acierto: 0.7051869
# Epoch: 1599 Pérdida: 0.4314537 Tasa de acierto: 0.7108678
# Epoch: 1699 Pérdida: 0.42723644 Tasa de acierto: 0.7155934
# Epoch: 1799 Pérdida: 0.4236718 Tasa de acierto: 0.7195253
# Epoch: 1899 Pérdida: 0.42054135 Tasa de acierto: 0.7228295
# Epoch: 1999 Pérdida: 0.4177149 Tasa de acierto: 0.72565055
# Epoch: 2099 Pérdida: 0.4151166 Tasa de acierto: 0.72810227
# Epoch: 2199 Pérdida: 0.4127028 Tasa de acierto: 0.73027045
# Epoch: 2299 Pérdida: 0.41044793 Tasa de acierto: 0.7322184
# Epoch: 2399 Pérdida: 0.40833634 Tasa de acierto: 0.7339921
# Epoch: 2499 Pérdida: 0.40635836 Tasa de acierto: 0.73562545
# Epoch: 2599 Pérdida: 0.4045069 Tasa de acierto: 0.7371435
# Epoch: 2699 Pérdida: 0.40277666 Tasa de acierto: 0.7385649
# Epoch: 2799 Pérdida: 0.40116248 Tasa de acierto: 0.73990315
# Epoch: 2899 Pérdida: 0.39965984 Tasa de acierto: 0.7411683
# Epoch: 2999 Pérdida: 0.39826387 Tasa de acierto: 0.74236786
# Epoch: 3099 Pérdida: 0.39696988 Tasa de acierto: 0.74350685
# Epoch: 3199 Pérdida: 0.39577287 Tasa de acierto: 0.74458957
# Epoch: 3299 Pérdida: 0.3946677 Tasa de acierto: 0.7456186
# Epoch: 3399 Pérdida: 0.39364895 Tasa de acierto: 0.74659646
# Epoch: 3499 Pérdida: 0.39271075 Tasa de acierto: 0.7475248
# Epoch: 3599 Pérdida: 0.3918469 Tasa de acierto: 0.7484057
# Epoch: 3699 Pérdida: 0.39105135 Tasa de acierto: 0.7492405
# Epoch: 3799 Pérdida: 0.3903176 Tasa de acierto: 0.7500311
# Epoch: 3899 Pérdida: 0.38963965 Tasa de acierto: 0.750779
# Epoch: 3999 Pérdida: 0.3890115 Tasa de acierto: 0.7514858
# Epoch: 4099 Pérdida: 0.38842776 Tasa de acierto: 0.7521534
# Epoch: 4199 Pérdida: 0.38788342 Tasa de acierto: 0.75278354
# Epoch: 4299 Pérdida: 0.387374 Tasa de acierto: 0.7533781
# Epoch: 4399 Pérdida: 0.38689548 Tasa de acierto: 0.7539391
# Epoch: 4499 Pérdida: 0.38644436 Tasa de acierto: 0.75446826
# Epoch: 4599 Pérdida: 0.38601756 Tasa de acierto: 0.7549675
# Epoch: 4699 Pérdida: 0.38561258 Tasa de acierto: 0.755439
# Epoch: 4799 Pérdida: 0.38522708 Tasa de acierto: 0.75588435
# Epoch: 4899 Pérdida: 0.3848591 Tasa de acierto: 0.7563054
# Epoch: 4999 Pérdida: 0.3845069 Tasa de acierto: 0.7567039
# Epoch: 5099 Pérdida: 0.38416916 Tasa de acierto: 0.75708145
# Epoch: 5199 Pérdida: 0.38384444 Tasa de acierto: 0.7574398
# Epoch: 5299 Pérdida: 0.3835318 Tasa de acierto: 0.7577801
# Epoch: 5399 Pérdida: 0.38323018 Tasa de acierto: 0.75810385
# Epoch: 5499 Pérdida: 0.38293868 Tasa de acierto: 0.75841224
# Epoch: 5599 Pérdida: 0.38265657 Tasa de acierto: 0.7587065
# Epoch: 5699 Pérdida: 0.3823832 Tasa de acierto: 0.7589878
# Epoch: 5799 Pérdida: 0.38211787 Tasa de acierto: 0.7592568
# Epoch: 5899 Pérdida: 0.38186008 Tasa de acierto: 0.7595147
# Epoch: 5999 Pérdida: 0.38160923 Tasa de acierto: 0.75976235
# Epoch: 6099 Pérdida: 0.38136497 Tasa de acierto: 0.76000035
# Epoch: 6199 Pérdida: 0.3811267 Tasa de acierto: 0.76022965
# Epoch: 6299 Pérdida: 0.3808941 Tasa de acierto: 0.7604507
# Epoch: 6399 Pérdida: 0.38066685 Tasa de acierto: 0.76066417
# Epoch: 6499 Pérdida: 0.38044447 Tasa de acierto: 0.76087075
# Epoch: 6599 Pérdida: 0.3802267 Tasa de acierto: 0.76107085
# Epoch: 6699 Pérdida: 0.38001323 Tasa de acierto: 0.7612651
# Epoch: 6799 Pérdida: 0.3798038 Tasa de acierto: 0.7614537
# Epoch: 6899 Pérdida: 0.37959817 Tasa de acierto: 0.7616374
# Epoch: 6999 Pérdida: 0.37939602 Tasa de acierto: 0.7618165
# Epoch: 7099 Pérdida: 0.3791972 Tasa de acierto: 0.76199126
# Epoch: 7199 Pérdida: 0.3790016 Tasa de acierto: 0.7621622
# Epoch: 7299 Pérdida: 0.37880886 Tasa de acierto: 0.7623295
# Epoch: 7399 Pérdida: 0.37861896 Tasa de acierto: 0.7624935
# Epoch: 7499 Pérdida: 0.37843168 Tasa de acierto: 0.7626546
# Epoch: 7599 Pérdida: 0.378247 Tasa de acierto: 0.76281303
# Epoch: 7699 Pérdida: 0.3780647 Tasa de acierto: 0.7629688
# Epoch: 7799 Pérdida: 0.37788478 Tasa de acierto: 0.7631224
# Epoch: 7899 Pérdida: 0.37770703 Tasa de acierto: 0.76327384
# Epoch: 7999 Pérdida: 0.3775315 Tasa de acierto: 0.7634234
# Epoch: 8099 Pérdida: 0.377358 Tasa de acierto: 0.76357114
# Epoch: 8199 Pérdida: 0.37718663 Tasa de acierto: 0.76371723
# Epoch: 8299 Pérdida: 0.3770171 Tasa de acierto: 0.7638618
# Epoch: 8399 Pérdida: 0.37684965 Tasa de acierto: 0.76400465
# Epoch: 8499 Pérdida: 0.376684 Tasa de acierto: 0.7641461
# Epoch: 8599 Pérdida: 0.37652013 Tasa de acierto: 0.7642861
# Epoch: 8699 Pérdida: 0.37635815 Tasa de acierto: 0.7644248
# Epoch: 8799 Pérdida: 0.3761978 Tasa de acierto: 0.76456183
# Epoch: 8899 Pérdida: 0.37603915 Tasa de acierto: 0.76469755
# Epoch: 8999 Pérdida: 0.37588215 Tasa de acierto: 0.7648319
# Epoch: 9099 Pérdida: 0.37572673 Tasa de acierto: 0.7649647
# Epoch: 9199 Pérdida: 0.3755729 Tasa de acierto: 0.765096
# Epoch: 9299 Pérdida: 0.37542048 Tasa de acierto: 0.7652257
# Epoch: 9399 Pérdida: 0.3752696 Tasa de acierto: 0.76535386
# Epoch: 9499 Pérdida: 0.3751201 Tasa de acierto: 0.7654802
# Epoch: 9599 Pérdida: 0.37497196 Tasa de acierto: 0.7656051
# Epoch: 9699 Pérdida: 0.37482512 Tasa de acierto: 0.76572835
# Epoch: 9799 Pérdida: 0.37467957 Tasa de acierto: 0.76584995
# Epoch: 9899 Pérdida: 0.37453526 Tasa de acierto: 0.76596963
# Epoch: 9999 Pérdida: 0.37439218 Tasa de acierto: 0.7660875

# %% [markdown]
# # Ejercicio
# Mejora tu implementación haciendo los siguientes cambios:
# 1. Sustituye las capas `OurDenseLayer` por capas [nn.Linear](https://docs.pytorch.org/docs/stable/generated/torch.nn.Linear.html) seguidas de operaciones [torch.sigmoid](https://docs.pytorch.org/docs/stable/generated/torch.sigmoid.html).
# 1. Reemplaza `OurNetwork` por [nn.Sequential](https://docs.pytorch.org/docs/stable/generated/torch.nn.Sequential.html).
# 1. Cambia el optimizador a [Adam](https://docs.pytorch.org/docs/stable/generated/torch.optim.Adam.html).
